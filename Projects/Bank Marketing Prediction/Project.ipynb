# %%
###############################################
# Author: Pedro Igor Salvador Alves
# Project: Bank Marketing Prediction
# Database Link: https://archive.ics.uci.edu/ml/datasets/bank+marketing
# Start Date: 31/12/2021
# Type: Data Science - Machine Learning 
###############################################

# %%
import pandas as pd

dataset = pd.read_csv("data/bank.csv")

# %%
dataset
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...         1    999         0
# 1      telephone   may         mon  ...         1    999         0
# 2      telephone   may         mon  ...         1    999         0
# 3      telephone   may         mon  ...         1    999         0
# 4      telephone   may         mon  ...         1    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41183   cellular   nov         fri  ...         1    999         0
# 41184   cellular   nov         fri  ...         1    999         0
# 41185   cellular   nov         fri  ...         2    999         0
# 41186   cellular   nov         fri  ...         1    999         0
# 41187   cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41183  nonexistent         -1.1          94.767          -50.8      1.028
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 21 columns]

# %%
#drop duration feature. The idea is understading if a client would buy a product before calling the client.
dataset = dataset.drop("duration", axis=1)

# %%
X = dataset.iloc[:, :-1]
Y = dataset.iloc[:, -1]

X = pd.get_dummies(X, drop_first=True)
Y = pd.get_dummies(Y, drop_first=True)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 157)

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier

ranfor1 = RandomForestClassifier(random_state = 157)
ranfor1.fit(X_train, Y_train.values.ravel())
Y_predict1 = ranfor1.predict(X_test)

# %%
#evaluate
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test, Y_predict1)
# Out:
# array([[10631,   353],
#        [  995,   378]], dtype=int64)

# %%
ranfor1.score(X_test, Y_test)
# Out:
# 0.890912033665129

# %%
#Recursive Feature Elimination
from sklearn.feature_selection import RFE

# %%
ranfor2 = RandomForestClassifier(random_state = 157)
rfe = RFE(estimator = ranfor2, n_features_to_select = 30, step=1)

# %%
rfe.fit(X, Y.values.ravel())
# Out:
# RFE(estimator=RandomForestClassifier(random_state=157), n_features_to_select=30)

# %%
X_train_rfe = rfe.transform(X_train)
X_test_rfe = rfe.transform(X_test)

# %%
ranfor2.fit(X_train_rfe, Y_train.values.ravel())
Y_predict2 = ranfor2.predict(X_test_rfe)

# %%
confusion_matrix(Y_test, Y_predict2)
# Out:
# array([[10607,   377],
#        [  981,   392]], dtype=int64)

# %%
ranfor2.score(X_test_rfe, Y_test)
# Out:
# 0.890102775754633

# %%
#ranking features
columns = list(X.columns)
rank = rfe.ranking_

# %%
feature_importance = ranfor1.feature_importances_

# %%
rfe_selected = pd.DataFrame()
rfe_selected = pd.concat([pd.DataFrame(columns), pd.DataFrame(rank), pd.DataFrame(feature_importance)], axis=1)
rfe_selected.columns = ["Feature Name", "Rank", "Feature Importance (Gini Index)"]

# %%
rfe_selected
# Out:
#                      Feature Name  Rank  Feature Importance (Gini Scale)
# 0                             age     1                         0.170767
# 1                        campaign     1                         0.083434
# 2                           pdays     1                         0.034975
# 3                        previous     1                         0.014687
# 4                    emp.var.rate     1                         0.019380
# 5                  cons.price.idx     1                         0.022327
# 6                   cons.conf.idx     1                         0.030267
# 7                       euribor3m     1                         0.129868
# 8                     nr.employed     1                         0.051898
# 9                 job_blue-collar     1                         0.013861
# 10               job_entrepreneur     5                         0.006996
# 11                  job_housemaid    10                         0.004971
# 12                 job_management     1                         0.011705
# 13                    job_retired     2                         0.007966
# 14              job_self-employed     4                         0.007091
# 15                   job_services     1                         0.010987
# 16                    job_student     8                         0.005815
# 17                 job_technician     1                         0.017426
# 18                 job_unemployed     9                         0.005263
# 19                    job_unknown    15                         0.002565
# 20                marital_married     1                         0.020686
# 21                 marital_single     1                         0.017350
# 22                marital_unknown    20                         0.000675
# 23             education_basic.6y     3                         0.007679
# 24             education_basic.9y     1                         0.012534
# 25          education_high.school     1                         0.017364
# 26           education_illiterate    22                         0.000417
# 27  education_professional.course     1                         0.012772
# 28    education_university.degree     1                         0.017920
# 29              education_unknown     1                         0.007874
# 30                default_unknown     1                         0.014511
# 31                    default_yes    23                         0.000002
# 32                housing_unknown    13                         0.003700
# 33                    housing_yes     1                         0.039114
# 34                   loan_unknown     6                         0.003490
# 35                       loan_yes     1                         0.023271
# 36              contact_telephone     1                         0.014981
# 37                      month_aug    17                         0.002484
# 38                      month_dec    21                         0.000943
# 39                      month_jul    14                         0.002595
# 40                      month_jun    16                         0.003068
# 41                      month_mar    11                         0.004809
# 42                      month_may    12                         0.005273
# 43                      month_nov    19                         0.002132
# 44                      month_oct     7                         0.006279
# 45                      month_sep    18                         0.002706
# 46                day_of_week_mon     1                         0.016135
# 47                day_of_week_thu     1                         0.016294
# 48                day_of_week_tue     1                         0.016180
# 49                day_of_week_wed     1                         0.016030
# 50           poutcome_nonexistent     1                         0.012508
# 51               poutcome_success     1                         0.025974
